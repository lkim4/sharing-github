# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/Users/laurakim/Downloads/us-education-datasets-unification-project/states_all.csv")
df
# Out:
#                     PRIMARY_KEY                 STATE  YEAR  ENROLL  \
# 0                  1992_ALABAMA               ALABAMA  1992     NaN
# 1                   1992_ALASKA                ALASKA  1992     NaN
# 2                  1992_ARIZONA               ARIZONA  1992     NaN
# 3                 1992_ARKANSAS              ARKANSAS  1992     NaN
# 4               1992_CALIFORNIA            CALIFORNIA  1992     NaN
# 5                 1992_COLORADO              COLORADO  1992     NaN
# 6              1992_CONNECTICUT           CONNECTICUT  1992     NaN
# 7                 1992_DELAWARE              DELAWARE  1992     NaN
# 8     1992_DISTRICT_OF_COLUMBIA  DISTRICT_OF_COLUMBIA  1992     NaN
# 9                  1992_FLORIDA               FLORIDA  1992     NaN
# 10                 1992_GEORGIA               GEORGIA  1992     NaN
# 11                  1992_HAWAII                HAWAII  1992     NaN
# 12                   1992_IDAHO                 IDAHO  1992     NaN
# ...

# %%
#1: determine all the variable types and find the fraction of the missing values for each variable:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1492 entries, 0 to 1491
# Data columns (total 25 columns):
# PRIMARY_KEY                     1492 non-null object
# STATE                           1492 non-null object
# YEAR                            1492 non-null int64
# ENROLL                          1229 non-null float64
# TOTAL_REVENUE                   1280 non-null float64
# FEDERAL_REVENUE                 1280 non-null float64
# STATE_REVENUE                   1280 non-null float64
# LOCAL_REVENUE                   1280 non-null float64
# TOTAL_EXPENDITURE               1280 non-null float64
# INSTRUCTION_EXPENDITURE         1280 non-null float64
# SUPPORT_SERVICES_EXPENDITURE    1280 non-null float64
# OTHER_EXPENDITURE               1229 non-null float64
# CAPITAL_OUTLAY_EXPENDITURE      1280 non-null float64
# GRADES_PK_G                     1319 non-null float64
# GRADES_KG_G                     1360 non-null float64
# ...

# %%
df.shape
# Out:
# (1492, 25)

# %%
#1492 rows with 25 columns.
#three data types: float, int, object

# %%
df.isnull().mean()*100
# Out:
# PRIMARY_KEY                      0.000000
# STATE                            0.000000
# YEAR                             0.000000
# ENROLL                          17.627346
# TOTAL_REVENUE                   14.209115
# FEDERAL_REVENUE                 14.209115
# STATE_REVENUE                   14.209115
# LOCAL_REVENUE                   14.209115
# TOTAL_EXPENDITURE               14.209115
# INSTRUCTION_EXPENDITURE         14.209115
# SUPPORT_SERVICES_EXPENDITURE    14.209115
# OTHER_EXPENDITURE               17.627346
# CAPITAL_OUTLAY_EXPENDITURE      14.209115
# GRADES_PK_G                     11.595174
# GRADES_KG_G                      8.847185
# GRADES_4_G                       8.780161
# GRADES_8_G                       8.780161
# GRADES_12_G                      8.780161
# GRADES_1_8_G                     8.780161
# GRADES_9_12_G                    8.780161
# GRADES_ALL_G                    11.595174
# AVG_MATH_4_SCORE                64.075067
# ...

# %%
#a lot of them have null values, except for the following columns: PRIMARY_KEY, STATE, YEAR.  They usually have NaN
#filled in but the data also has value "0" instead. So let's replace "0" with NaN and then get the average # of NaN again

# %%
for i in df.columns:
    df[i].replace(0, np.NaN, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1492 entries, 0 to 1491
# Data columns (total 25 columns):
# PRIMARY_KEY                     1492 non-null object
# STATE                           1492 non-null object
# YEAR                            1492 non-null int64
# ENROLL                          1229 non-null float64
# TOTAL_REVENUE                   1280 non-null float64
# FEDERAL_REVENUE                 1280 non-null float64
# STATE_REVENUE                   1252 non-null float64
# LOCAL_REVENUE                   1280 non-null float64
# TOTAL_EXPENDITURE               1280 non-null float64
# INSTRUCTION_EXPENDITURE         1280 non-null float64
# SUPPORT_SERVICES_EXPENDITURE    1280 non-null float64
# OTHER_EXPENDITURE               1229 non-null float64
# CAPITAL_OUTLAY_EXPENDITURE      1280 non-null float64
# GRADES_PK_G                     1317 non-null float64
# GRADES_KG_G                     1360 non-null float64
# ...

# %%
df.isnull().mean()*100
# Out:
# PRIMARY_KEY                      0.000000
# STATE                            0.000000
# YEAR                             0.000000
# ENROLL                          17.627346
# TOTAL_REVENUE                   14.209115
# FEDERAL_REVENUE                 14.209115
# STATE_REVENUE                   16.085791
# LOCAL_REVENUE                   14.209115
# TOTAL_EXPENDITURE               14.209115
# INSTRUCTION_EXPENDITURE         14.209115
# SUPPORT_SERVICES_EXPENDITURE    14.209115
# OTHER_EXPENDITURE               17.627346
# CAPITAL_OUTLAY_EXPENDITURE      14.209115
# GRADES_PK_G                     11.729223
# GRADES_KG_G                      8.847185
# GRADES_4_G                       8.780161
# GRADES_8_G                       8.780161
# GRADES_12_G                      8.780161
# GRADES_1_8_G                     8.780161
# GRADES_9_12_G                    8.780161
# GRADES_ALL_G                    11.595174
# AVG_MATH_4_SCORE                64.075067
# ...

# %%
#After replacing "0" with NaN, some of the column's average # of NaN changed:
#increased for: STATE_REVENUE, GRADES_PK_G

# %%
df['PRIMARY_KEY'].unique()
# Out:
# array(['1992_ALABAMA', '1992_ALASKA', '1992_ARIZONA', ...,
#        '2017_WEST_VIRGINIA', '2017_WISCONSIN', '2017_WYOMING'],
#       dtype=object)

# %%
df['PRIMARY_KEY'].nunique()
# Out:
# 1487

# %%
df['PRIMARY_KEY'].value_counts()
# Out:
# 2008_VIRGINIA                3
# 2010_DISTRICT_OF_COLUMBIA    2
# 2009_DISTRICT_OF_COLUMBIA    2
# 2008_DISTRICT_OF_COLUMBIA    2
# 2016_UTAH                    1
# 2011_TEXAS                   1
# 1999_OHIO                    1
# 2011_ALASKA                  1
# 1997_NEW_YORK                1
# 1996_IDAHO                   1
# 2007_SOUTH_DAKOTA            1
# 2016_MISSOURI                1
# 1993_ARKANSAS                1
# 2008_ALASKA                  1
# 2006_NEW_YORK                1
# 2007_CONNECTICUT             1
# 1996_VERMONT                 1
# 2017_ALASKA                  1
# 1992_PENNSYLVANIA            1
# 2016_OKLAHOMA                1
# 1997_MISSOURI                1
# 1996_RHODE_ISLAND            1
# 2006_VIRGINIA                1
# 2004_MONTANA                 1
# 2015_MISSISSIPPI             1
# 2014_OREGON                  1
# 2011_DISTRICT_OF_COLUMBIA    1
# 1997_ALABAMA                 1
# 2012_PUERTO_RICO             1
# 1999_ARIZONA                 1
# ...

# %%
#PRIMARY_KEY column does not have any missing value.

# %%
df.loc[1240:1251, :]
# Out:
#              PRIMARY_KEY          STATE  YEAR     ENROLL  TOTAL_REVENUE  \
# 1240         2016_HAWAII         HAWAII  2016   181995.0      3030519.0
# 1241          2016_IDAHO          IDAHO  2016   274849.0      2266490.0
# 1242       2016_ILLINOIS       ILLINOIS  2016  2030717.0     32908958.0
# 1243        2016_INDIANA        INDIANA  2016  1002696.0     12732161.0
# 1244           2016_IOWA           IOWA  2016   508014.0      6919477.0
# 1245         2016_KANSAS         KANSAS  2016   495545.0      6069563.0
# 1246       2016_KENTUCKY       KENTUCKY  2016   686440.0      7745928.0
# 1247      2016_LOUISIANA      LOUISIANA  2016   660561.0      8397136.0
# 1248          2016_MAINE          MAINE  2016   179879.0      2845391.0
# 1249       2016_MARYLAND       MARYLAND  2016   879196.0     14409321.0
# 1250  2016_MASSACHUSETTS  MASSACHUSETTS  2016   921029.0     17484704.0
# 1251       2016_MICHIGAN       MICHIGAN  2016  1335713.0     19416061.0
#
# ...

# %%
#VI, AS, BI, DD, GU, MP, PR, DOD_-_FOREIGN, BIE, ETC.: what are these states??

# %%
df['STATE'].unique()
# Out:
# array(['ALABAMA', 'ALASKA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA',
#        'COLORADO', 'CONNECTICUT', 'DELAWARE', 'DISTRICT_OF_COLUMBIA',
#        'FLORIDA', 'GEORGIA', 'HAWAII', 'IDAHO', 'ILLINOIS', 'INDIANA',
#        'IOWA', 'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MAINE', 'MARYLAND',
#        'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI',
#        'MISSOURI', 'MONTANA', 'NEBRASKA', 'NEVADA', 'NEW_HAMPSHIRE',
#        'NEW_JERSEY', 'NEW_MEXICO', 'NEW_YORK', 'NORTH_CAROLINA',
#        'NORTH_DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON', 'PENNSYLVANIA',
#        'RHODE_ISLAND', 'SOUTH_CAROLINA', 'SOUTH_DAKOTA', 'TENNESSEE',
#        'TEXAS', 'UTAH', 'VERMONT', 'VIRGINIA', 'WASHINGTON',
#        'WEST_VIRGINIA', 'WISCONSIN', 'WYOMING', 'AMERICAN_SAMOA',
#        'BUREAU_OF_INDIAN_AFFAIRS', 'DOD_DOMESTIC', 'DOD_OVERSEAS', 'GUAM',
#        'NORTHERN_MARIANAS', 'PUERTO_RICO', 'VIRGIN_ISLANDS', 'BI', 'DD',
#        'NORTHERN_MARIANA_ISLANDS', 'DEPARTMENT_OF_DEFENSE',
# ...

# %%
df['STATE'].value_counts()
# Out:
# DISTRICT_OF_COLUMBIA                        29
# VIRGINIA                                    28
# ALASKA                                      26
# CONNECTICUT                                 26
# WEST_VIRGINIA                               26
# MONTANA                                     26
# IOWA                                        26
# DELAWARE                                    26
# VERMONT                                     26
# ARKANSAS                                    26
# WASHINGTON                                  26
# MARYLAND                                    26
# WISCONSIN                                   26
# KANSAS                                      26
# HAWAII                                      26
# GEORGIA                                     26
# LOUISIANA                                   26
# ARIZONA                                     26
# SOUTH_DAKOTA                                26
# NEVADA                                      26
# ...

# %%
df['STATE'].nunique()
# Out:
# 80

# %%
df1=df.groupby('STATE').count().reset_index()
df1
# Out:
#                                        STATE  PRIMARY_KEY  YEAR  ENROLL  \
# 0                                    ALABAMA           26    26      24
# 1                                     ALASKA           26    26      24
# 2                             AMERICAN_SAMOA           22    22       0
# 3                                    ARIZONA           26    26      24
# 4                                   ARKANSAS           26    26      24
# 5                                         AS            1     1       0
# 6                                         BI            4     4       0
# 7                                        BIE            2     2       0
# 8                   BUREAU_OF_INDIAN_AFFAIRS            6     6       0
# 9                  BUREAU_OF_INDIAN_EDUCATIO            1     1       0
# 10                BUREAU_OF_INDIAN_EDUCATION            2     2       0
# 11                                CALIFORNIA           26    26      24
# ...

# %%
df1.loc[30:49,:]
# Out:
#             STATE  PRIMARY_KEY  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 30           GUAM           23    23       0              0                0
# 31         HAWAII           26    26      24             25               25
# 32          IDAHO           26    26      24             25               25
# 33       ILLINOIS           26    26      24             25               25
# 34        INDIANA           26    26      24             25               25
# 35           IOWA           26    26      24             25               25
# 36         KANSAS           26    26      24             25               25
# 37       KENTUCKY           26    26      24             25               25
# 38      LOUISIANA           26    26      24             25               25
# 39          MAINE           26    26      24             25               25
# 40       MARIANAS            1     1       0              0                0
# ...

# %%
#STATE column does not have any missing value either

# %%
df.YEAR.unique()
# Out:
# array([1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017])

# %%
df.YEAR.value_counts()
# Out:
# 2004    59
# 2008    59
# 1999    59
# 2000    59
# 2001    59
# 2002    59
# 2003    59
# 2005    59
# 2007    59
# 2006    59
# 2009    59
# 2010    58
# 2011    58
# 2012    58
# 2013    58
# 1998    58
# 2015    57
# 1997    57
# 1996    57
# 1995    56
# 1994    56
# 1993    56
# 1992    56
# 2014    56
# 2016    51
# 2017    51
# Name: YEAR, dtype: int64

# %%
df2=df.groupby(['YEAR']).count().reset_index()
df2
# Out:
#     YEAR  PRIMARY_KEY  STATE  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0   1992           56     56       0             51               51
# 1   1993           56     56      51             51               51
# 2   1994           56     56      51             51               51
# 3   1995           56     56      51             51               51
# 4   1996           57     57      51             51               51
# 5   1997           57     57      51             51               51
# 6   1998           58     58      51             51               51
# 7   1999           59     59      51             51               51
# 8   2000           59     59      51             51               51
# 9   2001           59     59      51             51               51
# 10  2002           59     59      51             51               51
# 11  2003           59     59      51             51               51
# 12  2004           59     59      51             51               51
# ...

# %%
df2['PRIMARY_KEY'].sum()
# Out:
# 1492

# %%
#YEAR column does not have any missing value as well

# %%
#2: when ignoring YEAR, drop, fill in missing values:

# %%
df3=df.drop(['PRIMARY_KEY', 'YEAR'], axis=1)
df3
# Out:
#                      STATE  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0                  ALABAMA     NaN      2678885.0         304177.0
# 1                   ALASKA     NaN      1049591.0         106780.0
# 2                  ARIZONA     NaN      3258079.0         297888.0
# 3                 ARKANSAS     NaN      1711959.0         178571.0
# 4               CALIFORNIA     NaN     26260025.0        2072470.0
# 5                 COLORADO     NaN      3185173.0         163253.0
# 6              CONNECTICUT     NaN      3834302.0         143542.0
# 7                 DELAWARE     NaN       645233.0          45945.0
# 8     DISTRICT_OF_COLUMBIA     NaN       709480.0          64749.0
# 9                  FLORIDA     NaN     11506299.0         788420.0
# 10                 GEORGIA     NaN      5536901.0         398701.0
# 11                  HAWAII     NaN       996809.0          71273.0
# 12                   IDAHO     NaN       859329.0          69138.0
# ...

# %%
df3.columns
# Out:
# Index(['STATE', 'ENROLL', 'TOTAL_REVENUE', 'FEDERAL_REVENUE', 'STATE_REVENUE',
#        'LOCAL_REVENUE', 'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE',
#        'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE',
#        'CAPITAL_OUTLAY_EXPENDITURE', 'GRADES_PK_G', 'GRADES_KG_G',
#        'GRADES_4_G', 'GRADES_8_G', 'GRADES_12_G', 'GRADES_1_8_G',
#        'GRADES_9_12_G', 'GRADES_ALL_G', 'AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE',
#        'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE'],
#       dtype='object')

# %%
df3['ENROLL'].max()
# Out:
# 6307022.0

# %%
df3[df3['ENROLL']==6307022]
# Out:
#           STATE     ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  \
# 667  CALIFORNIA  6307022.0     62171797.0        7148863.0     34912166.0
#
#      LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 667     20110768.0         66196072.0               31070450.0
#
#      SUPPORT_SERVICES_EXPENDITURE  OTHER_EXPENDITURE         ...           \
# 667                    18046385.0          3132465.0         ...
#
#      GRADES_4_G  GRADES_8_G  GRADES_12_G  GRADES_1_8_G  GRADES_9_12_G  \
# 667    477828.0    489560.0     423241.0     3848455.0      1953077.0
#
#      GRADES_ALL_G  AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# 667     5926631.0        230.366957        268.558129           206.512026
#
#      AVG_READING_8_SCORE
# 667            264.18451
#
# [1 rows x 23 columns]

# %%
df3['ENROLL'].min()
# Out:
# 43866.0

# %%
df3['ENROLL'].describe()
# Out:
# count    1.229000e+03
# mean     9.159308e+05
# std      1.065280e+06
# min      4.386600e+04
# 25%      2.583140e+05
# 50%      6.483130e+05
# 75%      1.014528e+06
# max      6.307022e+06
# Name: ENROLL, dtype: float64

# %%
#drop all the rows with STATE names that do not any sense

# %%
variable=df3[(df3['STATE']=='DOD_FOREIGN') & (df3['STATE']=='VI') & (df3['STATE']=='AS') & (df3['STATE']=='BI') & (df3['STATE']=='DD') & (df3['STATE']=='BIE') & (df3['STATE']=='GU') & (df3['STATE']=='MP') & (df3['STATE']=='PR')].index
df3.drop(variable, inplace=True)
df3
# Out:
#                      STATE  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0                  ALABAMA     NaN      2678885.0         304177.0
# 1                   ALASKA     NaN      1049591.0         106780.0
# 2                  ARIZONA     NaN      3258079.0         297888.0
# 3                 ARKANSAS     NaN      1711959.0         178571.0
# 4               CALIFORNIA     NaN     26260025.0        2072470.0
# 5                 COLORADO     NaN      3185173.0         163253.0
# 6              CONNECTICUT     NaN      3834302.0         143542.0
# 7                 DELAWARE     NaN       645233.0          45945.0
# 8     DISTRICT_OF_COLUMBIA     NaN       709480.0          64749.0
# 9                  FLORIDA     NaN     11506299.0         788420.0
# 10                 GEORGIA     NaN      5536901.0         398701.0
# 11                  HAWAII     NaN       996809.0          71273.0
# 12                   IDAHO     NaN       859329.0          69138.0
# ...

# %%
df.loc[df['STATE']=='ALABAMA']
# Out:
#        PRIMARY_KEY    STATE  YEAR    ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA  ALABAMA  1992       NaN      2678885.0         304177.0
# 51    1993_ALABAMA  ALABAMA  1993  727716.0      2827391.0         331409.0
# 102   1994_ALABAMA  ALABAMA  1994  730004.0      2970223.0         331823.0
# 153   1995_ALABAMA  ALABAMA  1995  727480.0      3367437.0         328957.0
# 204   1996_ALABAMA  ALABAMA  1996  735912.0      3365113.0         334858.0
# 255   1997_ALABAMA  ALABAMA  1997  737386.0      3981788.0         376200.0
# 306   1998_ALABAMA  ALABAMA  1998  739321.0      4140537.0         374153.0
# 357   1999_ALABAMA  ALABAMA  1999  737639.0      4471546.0         393095.0
# 408   2000_ALABAMA  ALABAMA  2000  730184.0      4885917.0         425978.0
# 459   2001_ALABAMA  ALABAMA  2001  728532.0      4832946.0         466150.0
# 510   2002_ALABAMA  ALABAMA  2002  726367.0      5128559.0         508425.0
# ...

# %%
df.loc[df['STATE']=='CALIFORNIA']
# Out:
#           PRIMARY_KEY       STATE  YEAR     ENROLL  TOTAL_REVENUE  \
# 4     1992_CALIFORNIA  CALIFORNIA  1992        NaN     26260025.0
# 55    1993_CALIFORNIA  CALIFORNIA  1993  5129788.0     28043338.0
# 106   1994_CALIFORNIA  CALIFORNIA  1994  4120498.0     23440845.0
# 157   1995_CALIFORNIA  CALIFORNIA  1995  5299405.0     29512214.0
# 208   1996_CALIFORNIA  CALIFORNIA  1996  5460484.0     31282981.0
# 259   1997_CALIFORNIA  CALIFORNIA  1997  5595836.0     35614934.0
# 310   1998_CALIFORNIA  CALIFORNIA  1998  5727224.0     39183018.0
# 361   1999_CALIFORNIA  CALIFORNIA  1999  5839207.0     41393435.0
# 412   2000_CALIFORNIA  CALIFORNIA  2000  5941946.0     46628207.0
# 463   2001_CALIFORNIA  CALIFORNIA  2001  6045030.0     53288943.0
# 514   2002_CALIFORNIA  CALIFORNIA  2002  6136915.0     54727056.0
# 565   2003_CALIFORNIA  CALIFORNIA  2003  6226552.0     59815855.0
# 616   2004_CALIFORNIA  CALIFORNIA  2004  6284502.0     60162326.0
# ...

# %%
df.loc[df['STATE']=='VIRGINIA']
# Out:
#         PRIMARY_KEY     STATE  YEAR     ENROLL  TOTAL_REVENUE  \
# 46    1992_VIRGINIA  VIRGINIA  1992        NaN      5631293.0
# 97    1993_VIRGINIA  VIRGINIA  1993  1032842.0      5918536.0
# 148   1994_VIRGINIA  VIRGINIA  1994  1044721.0      6125739.0
# 199   1995_VIRGINIA  VIRGINIA  1995  1060809.0      6354418.0
# 250   1996_VIRGINIA  VIRGINIA  1996  1079854.0      6674519.0
# 301   1997_VIRGINIA  VIRGINIA  1997  1096279.0      7345090.0
# 352   1998_VIRGINIA  VIRGINIA  1998  1110815.0      7723744.0
# 403   1999_VIRGINIA  VIRGINIA  1999  1122858.0      8331336.0
# 454   2000_VIRGINIA  VIRGINIA  2000  1132673.0      8911426.0
# 505   2001_VIRGINIA  VIRGINIA  2001  1143807.0      9493862.0
# 556   2002_VIRGINIA  VIRGINIA  2002  1162045.0      9914221.0
# 607   2003_VIRGINIA  VIRGINIA  2003  1175458.0     10504167.0
# 658   2004_VIRGINIA  VIRGINIA  2004  1191035.0     11151172.0
# 709   2005_VIRGINIA  VIRGINIA  2005  1203697.0     12182657.0
# ...

# %%
df.loc[df['STATE']=='TEXAS']
# Out:
#      PRIMARY_KEY  STATE  YEAR     ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 43    1992_TEXAS  TEXAS  1992        NaN     16264180.0        1160185.0
# 94    1993_TEXAS  TEXAS  1993  3535333.0     20267205.0        1233446.0
# 145   1994_TEXAS  TEXAS  1994  3601627.0     19713604.0        1456330.0
# 196   1995_TEXAS  TEXAS  1995  3670007.0     20483376.0        1496378.0
# 247   1996_TEXAS  TEXAS  1996  3740260.0     22241369.0        1613462.0
# 298   1997_TEXAS  TEXAS  1997  3826366.0     23091567.0        1688975.0
# 349   1998_TEXAS  TEXAS  1998  3888061.0     24485263.0        1830474.0
# 400   1999_TEXAS  TEXAS  1999  3933017.0     26096023.0        2161662.0
# 451   2000_TEXAS  TEXAS  2000  3965971.0     28918934.0        2406972.0
# 502   2001_TEXAS  TEXAS  2001  4021535.0     30868844.0        2631160.0
# 553   2002_TEXAS  TEXAS  2002  4112315.0     32802734.0        2941562.0
# 604   2003_TEXAS  TEXAS  2003  4201914.0     35143236.0        3360082.0
# ...

# %%
df3['ENROLL']=df3['ENROLL'].fillna(df3.groupby('STATE')['ENROLL'].transform('mean'))

# %%
df3['TOTAL_REVENUE']=df3['TOTAL_REVENUE'].fillna(df3.groupby('STATE')['TOTAL_REVENUE'].transform('mean'))

# %%
df3['FEDERAL_REVENUE']=df3['FEDERAL_REVENUE'].fillna(df3.groupby('STATE')['FEDERAL_REVENUE'].transform('mean'))

# %%
df3['STATE_REVENUE']=df3['STATE_REVENUE'].fillna(df3.groupby('STATE')['STATE_REVENUE'].transform('mean'))

# %%
df3['LOCAL_REVENUE']=df3['LOCAL_REVENUE'].fillna(df3.groupby('STATE')['LOCAL_REVENUE'].transform('mean'))

# %%
df3['TOTAL_EXPENDITURE']=df3['TOTAL_EXPENDITURE'].fillna(df3.groupby('STATE')['TOTAL_EXPENDITURE'].transform('mean'))

# %%
df3['INSTRUCTION_EXPENDITURE']=df3['INSTRUCTION_EXPENDITURE'].fillna(df3.groupby('STATE')['INSTRUCTION_EXPENDITURE'].transform('mean'))

# %%
df3['SUPPORT_SERVICES_EXPENDITURE']=df3['SUPPORT_SERVICES_EXPENDITURE'].fillna(df3.groupby('STATE')['SUPPORT_SERVICES_EXPENDITURE'].transform('mean'))

# %%
df3['OTHER_EXPENDITURE']=df3['OTHER_EXPENDITURE'].fillna(df3.groupby('STATE')['OTHER_EXPENDITURE'].transform('mean'))

# %%
df3['GRADES_4_G']=df3['GRADES_4_G'].fillna(df3.groupby('STATE')['GRADES_4_G'].transform('mean'))

# %%
df3['GRADES_8_G']=df3['GRADES_8_G'].fillna(df3.groupby('STATE')['GRADES_8_G'].transform('mean'))

# %%
df3['GRADES_12_G']=df3['GRADES_12_G'].fillna(df3.groupby('STATE')['GRADES_12_G'].transform('mean'))

# %%
df3['GRADES_1_8_G']=df3['GRADES_1_8_G'].fillna(df3.groupby('STATE')['GRADES_1_8_G'].transform('mean'))

# %%
df3['GRADES_9_12_G']=df3['GRADES_9_12_G'].fillna(df3.groupby('STATE')['GRADES_9_12_G'].transform('mean'))

# %%
df3['GRADES_ALL_G']=df3['GRADES_ALL_G'].fillna(df3.groupby('STATE')['GRADES_ALL_G'].transform('mean'))

# %%
df3['AVG_MATH_4_SCORE']=df3['AVG_MATH_4_SCORE'].fillna(df3.groupby('STATE')['AVG_MATH_4_SCORE'].transform('mean'))

# %%
df3['AVG_MATH_8_SCORE']=df3['AVG_MATH_8_SCORE'].fillna(df3.groupby('STATE')['AVG_MATH_8_SCORE'].transform('mean'))

# %%
df3['AVG_READING_4_SCORE']=df3['AVG_READING_4_SCORE'].fillna(df3.groupby('STATE')['AVG_READING_4_SCORE'].transform('mean'))

# %%
df3['AVG_READING_8_SCORE']=df3['AVG_READING_8_SCORE'].fillna(df3.groupby('STATE')['AVG_READING_8_SCORE'].transform('mean'))

# %%
df3
# Out:
#                      STATE        ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0                  ALABAMA  7.365843e+05     2678885.00     3.041770e+05
# 1                   ALASKA  1.304296e+05     1049591.00     1.067800e+05
# 2                  ARIZONA  8.743221e+05     3258079.00     2.978880e+05
# 3                 ARKANSAS  4.519019e+05     1711959.00     1.785710e+05
# 4               CALIFORNIA  5.945343e+06    26260025.00     2.072470e+06
# 5                 COLORADO  7.515678e+05     3185173.00     1.632530e+05
# 6              CONNECTICUT  5.231307e+05     3834302.00     1.435420e+05
# 7                 DELAWARE  1.136383e+05      645233.00     4.594500e+04
# 8     DISTRICT_OF_COLUMBIA  6.053119e+04      709480.00     6.474900e+04
# 9                  FLORIDA  2.486441e+06    11506299.00     7.884200e+05
# 10                 GEORGIA  1.503696e+06     5536901.00     3.987010e+05
# 11                  HAWAII  1.834175e+05      996809.00     7.127300e+04
# ...

# %%
#in the table above, ignoring the year, I filled in all the missing values with each state's average value.
#however, when I looked at few states like ALABAMA, CALIFORNIA, TEXAS, VIRGINIA as examples, USUALLY 
#the values stay about the same as the previous row.  
#so instead of filling in missing values with the average,
#I think it's better to replace them with 
#previous row's value if I were to consider YEARS.
#I know that question 3 asks to fill in the missing value using the average value of each year.  However, when I 
#look at those 4 example states, only one value is available for each year, so I can't get the average with just one
#value.  I don't think I should take the average of the column for each year of different states.  

#sort by YEAR, groupby state

# %%
#fill in with previous row example: df.fillna(method='ffill', inplace=True)

# %%
#df['ENROLL'].fillna(method='backfill', inplace=True)

# %%
df5=df.drop('PRIMARY_KEY', axis=1)
df6=df5.groupby('STATE').apply(lambda x: x.sort_values('YEAR'))
df6
# Out:
#                     STATE  YEAR    ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# STATE
# ALABAMA   0       ALABAMA  1992       NaN      2678885.0         304177.0
#           51      ALABAMA  1993  727716.0      2827391.0         331409.0
#           102     ALABAMA  1994  730004.0      2970223.0         331823.0
#           153     ALABAMA  1995  727480.0      3367437.0         328957.0
#           204     ALABAMA  1996  735912.0      3365113.0         334858.0
#           255     ALABAMA  1997  737386.0      3981788.0         376200.0
#           306     ALABAMA  1998  739321.0      4140537.0         374153.0
#           357     ALABAMA  1999  737639.0      4471546.0         393095.0
#           408     ALABAMA  2000  730184.0      4885917.0         425978.0
#           459     ALABAMA  2001  728532.0      4832946.0         466150.0
#           510     ALABAMA  2002  726367.0      5128559.0         508425.0
#           561     ALABAMA  2003  727900.0      5196054.0         567704.0
# ...

# %%
df6.isnull().any()
# Out:
# STATE                           False
# YEAR                            False
# ENROLL                           True
# TOTAL_REVENUE                    True
# FEDERAL_REVENUE                  True
# STATE_REVENUE                    True
# LOCAL_REVENUE                    True
# TOTAL_EXPENDITURE                True
# INSTRUCTION_EXPENDITURE          True
# SUPPORT_SERVICES_EXPENDITURE     True
# OTHER_EXPENDITURE                True
# CAPITAL_OUTLAY_EXPENDITURE       True
# GRADES_PK_G                      True
# GRADES_KG_G                      True
# GRADES_4_G                       True
# GRADES_8_G                       True
# GRADES_12_G                      True
# GRADES_1_8_G                     True
# GRADES_9_12_G                    True
# GRADES_ALL_G                     True
# AVG_MATH_4_SCORE                 True
# AVG_MATH_8_SCORE                 True
# AVG_READING_4_SCORE              True
# AVG_READING_8_SCORE              True
# dtype: bool

# %%
df6.iloc[1491,2]=94511.0
df6.iloc[1491,3]=2044669.0
df6.iloc[1491,4]=123012.0
df6.iloc[1491,5]=1175899.0
df6.iloc[1491,6]=745758.0
df6.iloc[1491,7]=2034229.0
df6.iloc[1491,8]=921494.0
df6.iloc[1491,9]=585700.0
df6.iloc[1490,14]=7551.0
df6.iloc[1490,15]=6902.0
df6.iloc[1490,16]=6299.0
df6.iloc[1490,17]=59453.0
df6.iloc[1490,18]=26914.0
df6.iloc[1490,19]=86876.0
df6.iloc[1490,20]=246.759764
df6.iloc[1490,21]=286.666547
df6.iloc[1490,22]=228.160803
df6.iloc[1490,23]=260.185273
df6.iloc[1491,15]=7551.0
df6.iloc[1491,16]=6902.0
df6.iloc[1491,17]=6299.0
df6.iloc[1491,18]=59453.0
df6.iloc[1491,19]=26914.0
df6.iloc[1491,20]=86876.0
df6
# Out:
#                     STATE  YEAR    ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# STATE
# ALABAMA   0       ALABAMA  1992       NaN      2678885.0         304177.0
#           51      ALABAMA  1993  727716.0      2827391.0         331409.0
#           102     ALABAMA  1994  730004.0      2970223.0         331823.0
#           153     ALABAMA  1995  727480.0      3367437.0         328957.0
#           204     ALABAMA  1996  735912.0      3365113.0         334858.0
#           255     ALABAMA  1997  737386.0      3981788.0         376200.0
#           306     ALABAMA  1998  739321.0      4140537.0         374153.0
#           357     ALABAMA  1999  737639.0      4471546.0         393095.0
#           408     ALABAMA  2000  730184.0      4885917.0         425978.0
#           459     ALABAMA  2001  728532.0      4832946.0         466150.0
#           510     ALABAMA  2002  726367.0      5128559.0         508425.0
#           561     ALABAMA  2003  727900.0      5196054.0         567704.0
# ...

# %%
df6.isnull().any()
# Out:
# STATE                           False
# YEAR                            False
# ENROLL                           True
# TOTAL_REVENUE                    True
# FEDERAL_REVENUE                  True
# STATE_REVENUE                    True
# LOCAL_REVENUE                    True
# TOTAL_EXPENDITURE                True
# INSTRUCTION_EXPENDITURE          True
# SUPPORT_SERVICES_EXPENDITURE     True
# OTHER_EXPENDITURE                True
# CAPITAL_OUTLAY_EXPENDITURE       True
# GRADES_PK_G                      True
# GRADES_KG_G                      True
# GRADES_4_G                       True
# GRADES_8_G                       True
# GRADES_12_G                      True
# GRADES_1_8_G                     True
# GRADES_9_12_G                    True
# GRADES_ALL_G                     True
# AVG_MATH_4_SCORE                 True
# AVG_MATH_8_SCORE                 True
# AVG_READING_4_SCORE              True
# AVG_READING_8_SCORE              True
# dtype: bool

# %%
df6.fillna(method='ffill', inplace=True)
df6
# Out:
#                     STATE  YEAR    ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# STATE
# ALABAMA   0       ALABAMA  1992       NaN      2678885.0         304177.0
#           51      ALABAMA  1993  727716.0      2827391.0         331409.0
#           102     ALABAMA  1994  730004.0      2970223.0         331823.0
#           153     ALABAMA  1995  727480.0      3367437.0         328957.0
#           204     ALABAMA  1996  735912.0      3365113.0         334858.0
#           255     ALABAMA  1997  737386.0      3981788.0         376200.0
#           306     ALABAMA  1998  739321.0      4140537.0         374153.0
#           357     ALABAMA  1999  737639.0      4471546.0         393095.0
#           408     ALABAMA  2000  730184.0      4885917.0         425978.0
#           459     ALABAMA  2001  728532.0      4832946.0         466150.0
#           510     ALABAMA  2002  726367.0      5128559.0         508425.0
#           561     ALABAMA  2003  727900.0      5196054.0         567704.0
# ...

# %%
df6.isnull().any()
# Out:
# STATE                           False
# YEAR                            False
# ENROLL                           True
# TOTAL_REVENUE                   False
# FEDERAL_REVENUE                 False
# STATE_REVENUE                   False
# LOCAL_REVENUE                   False
# TOTAL_EXPENDITURE               False
# INSTRUCTION_EXPENDITURE         False
# SUPPORT_SERVICES_EXPENDITURE    False
# OTHER_EXPENDITURE                True
# CAPITAL_OUTLAY_EXPENDITURE      False
# GRADES_PK_G                     False
# GRADES_KG_G                     False
# GRADES_4_G                      False
# GRADES_8_G                      False
# GRADES_12_G                     False
# GRADES_1_8_G                    False
# GRADES_9_12_G                   False
# GRADES_ALL_G                    False
# AVG_MATH_4_SCORE                False
# AVG_MATH_8_SCORE                False
# AVG_READING_4_SCORE             False
# AVG_READING_8_SCORE              True
# dtype: bool

# %%
df6.iloc[0,2]=727716.0
df6.iloc[0:4,23]=260.276441
df6.isnull().any()
# Out:
# STATE                           False
# YEAR                            False
# ENROLL                          False
# TOTAL_REVENUE                   False
# FEDERAL_REVENUE                 False
# STATE_REVENUE                   False
# LOCAL_REVENUE                   False
# TOTAL_EXPENDITURE               False
# INSTRUCTION_EXPENDITURE         False
# SUPPORT_SERVICES_EXPENDITURE    False
# OTHER_EXPENDITURE                True
# CAPITAL_OUTLAY_EXPENDITURE      False
# GRADES_PK_G                     False
# GRADES_KG_G                     False
# GRADES_4_G                      False
# GRADES_8_G                      False
# GRADES_12_G                     False
# GRADES_1_8_G                    False
# GRADES_9_12_G                   False
# GRADES_ALL_G                    False
# AVG_MATH_4_SCORE                False
# AVG_MATH_8_SCORE                False
# AVG_READING_4_SCORE             False
# AVG_READING_8_SCORE             False
# dtype: bool

# %%
df6.iloc[0,10]=237222.0

# %%
df6.isnull().any()
# Out:
# STATE                           False
# YEAR                            False
# ENROLL                          False
# TOTAL_REVENUE                   False
# FEDERAL_REVENUE                 False
# STATE_REVENUE                   False
# LOCAL_REVENUE                   False
# TOTAL_EXPENDITURE               False
# INSTRUCTION_EXPENDITURE         False
# SUPPORT_SERVICES_EXPENDITURE    False
# OTHER_EXPENDITURE               False
# CAPITAL_OUTLAY_EXPENDITURE      False
# GRADES_PK_G                     False
# GRADES_KG_G                     False
# GRADES_4_G                      False
# GRADES_8_G                      False
# GRADES_12_G                     False
# GRADES_1_8_G                    False
# GRADES_9_12_G                   False
# GRADES_ALL_G                    False
# AVG_MATH_4_SCORE                False
# AVG_MATH_8_SCORE                False
# AVG_READING_4_SCORE             False
# AVG_READING_8_SCORE             False
# dtype: bool

# %%
df8=df6.interpolate(method='linear', limit_direction='forward', axis=0)
df8
# Out:
#                     STATE  YEAR    ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# STATE
# ALABAMA   0       ALABAMA  1992  727716.0      2678885.0         304177.0
#           51      ALABAMA  1993  727716.0      2827391.0         331409.0
#           102     ALABAMA  1994  730004.0      2970223.0         331823.0
#           153     ALABAMA  1995  727480.0      3367437.0         328957.0
#           204     ALABAMA  1996  735912.0      3365113.0         334858.0
#           255     ALABAMA  1997  737386.0      3981788.0         376200.0
#           306     ALABAMA  1998  739321.0      4140537.0         374153.0
#           357     ALABAMA  1999  737639.0      4471546.0         393095.0
#           408     ALABAMA  2000  730184.0      4885917.0         425978.0
#           459     ALABAMA  2001  728532.0      4832946.0         466150.0
#           510     ALABAMA  2002  726367.0      5128559.0         508425.0
#           561     ALABAMA  2003  727900.0      5196054.0         567704.0
# ...

# %%
df8.isnull().any()
# Out:
# STATE                           False
# YEAR                            False
# ENROLL                          False
# TOTAL_REVENUE                   False
# FEDERAL_REVENUE                 False
# STATE_REVENUE                   False
# LOCAL_REVENUE                   False
# TOTAL_EXPENDITURE               False
# INSTRUCTION_EXPENDITURE         False
# SUPPORT_SERVICES_EXPENDITURE    False
# OTHER_EXPENDITURE               False
# CAPITAL_OUTLAY_EXPENDITURE      False
# GRADES_PK_G                     False
# GRADES_KG_G                     False
# GRADES_4_G                      False
# GRADES_8_G                      False
# GRADES_12_G                     False
# GRADES_1_8_G                    False
# GRADES_9_12_G                   False
# GRADES_ALL_G                    False
# AVG_MATH_4_SCORE                False
# AVG_MATH_8_SCORE                False
# AVG_READING_4_SCORE             False
# AVG_READING_8_SCORE             False
# dtype: bool

# %%
df8.iloc[0,2]=727716.000000
df8.iloc[0:4, 23]=260.276441
df8.iloc[0, 10]=237222.00000

# %%
df8.isnull().any()
# Out:
# STATE                           False
# YEAR                            False
# ENROLL                          False
# TOTAL_REVENUE                   False
# FEDERAL_REVENUE                 False
# STATE_REVENUE                   False
# LOCAL_REVENUE                   False
# TOTAL_EXPENDITURE               False
# INSTRUCTION_EXPENDITURE         False
# SUPPORT_SERVICES_EXPENDITURE    False
# OTHER_EXPENDITURE               False
# CAPITAL_OUTLAY_EXPENDITURE      False
# GRADES_PK_G                     False
# GRADES_KG_G                     False
# GRADES_4_G                      False
# GRADES_8_G                      False
# GRADES_12_G                     False
# GRADES_1_8_G                    False
# GRADES_9_12_G                   False
# GRADES_ALL_G                    False
# AVG_MATH_4_SCORE                False
# AVG_MATH_8_SCORE                False
# AVG_READING_4_SCORE             False
# AVG_READING_8_SCORE             False
# dtype: bool

# %%
#17.4 assignment: TOTAL_REVENUE AND TOTAL_EXPENDITURE OUTLIERS:

# %%
#TOTAL_REVENUE: checking for outliers using visual and stat:

# %%
plt.boxplot(df8['TOTAL_REVENUE'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a1f347908>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a1f347f98>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a1f347518>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a1f33e668>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a1f33e9b0>],
#  'means': []}

# %%
#many outliers when the whis=1.5
#using stats: zscore with varying threshold: 1, 1.5, 2, 2.5

# %%
from scipy.stats import zscore

# %%
#z_score_total_revenue=zscore(df8['TOTAL_REVENUE'])
#for threshold in np.arange (1,3, 0.5):
    #print ("for threshold {}".format(threshold))
    #print ("number of outliers: {}".format(len(np.where(z_score_total_revenue>threshold)[0])))

# %%
#will using Tukey's method also give 105 with whis=1.5??

# %%
q75, q25=np.percentile(df8['TOTAL_REVENUE'], [75,25])
iqr=q75-q25
max_value=q75 + (iqr*1.5)
min_value=q25-(iqr*1.5)
print("Number of outliers using Tukey's method: {}".format(len(np.where((df8['TOTAL_REVENUE']>max_value) |(df8['TOTAL_REVENUE']<min_value))[0])))
# Out:
# Number of outliers using Tukey's method: 129

# %%
#how come using Tukey's method (129 outliers with threshold 1.5) and zscore (105 with threshold 1.5) 
#give different number of outliers?
#higher the zscore, farther away that value is from the mean.

# %%
plt.boxplot(df8['TOTAL_EXPENDITURE'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a1ff1c320>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a1ff1c9b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a1ff12ef0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a1ff1cdd8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a1ff243c8>],
#  'means': []}

# %%
q75_exp, q25_exp=np.percentile(df8['TOTAL_EXPENDITURE'], [75,25])
iqr2=q75_exp - q25_exp
max_value2=q75_exp + (iqr2*1.5)
min_value2=q25_exp -(iqr2*1.5)
print("Number of outliers using Tukey's method: {}".format(len(np.where((df8['TOTAL_EXPENDITURE']>max_value2) |(df8['TOTAL_EXPENDITURE']<min_value2))[0])))
# Out:
# Number of outliers using Tukey's method: 133

# %%
#z_score_total_exp=zscore(df8['TOTAL_EXPENDITURE'])
#for threshold in np.arange (1,3, 0.5):
    #print ("for threshold {}".format(threshold))
    #print ("number of outliers: {}".format(len(np.where(z_score_total_exp>threshold)[0])))

# %%
#2: eliminiate outliers then validate that there's no outlier.
#to do this, I'm going to set threshold to be 1.5 first.

# %%
#df8.drop(df8.loc[(df8['TOTAL_REVENUE']>143).index, inplace=True])
#df8.drop(df8.loc[(df8['TOTAL_EXPENDITURE']>max_value2) & (df8['TOTAL_EXPENDITURE']<min_value2)].index, inplace=True)

# %%
max_value
# Out:
# 27622385.875

# %%
max_value2
# Out:
# 27575952.625

# %%
#q75_exp2, q25_exp=np.percentile(df8['TOTAL_EXPENDITURE'], [75,25])
#iqr2=q75_exp - q25_exp
#max_value2=q75_exp + (iqr2*1.5)
#min_value2=q25_exp -(iqr2*1.5)
#print("Number of outliers using Tukey's method: {}".format(len(np.where((df8['TOTAL_EXPENDITURE']>max_value2) |(df8['TOTAL_EXPENDITURE']<min_value2))[0])))

# %%
#df8['TOTAL_REVENUE']=df8.drop(df8[df8['TOTAL_REVENUE']>max_value].index, inplace=True)

# %%
#df8['TOTAL_EXPENDITURE']=df8.drop(df8[df8['TOTAL_EXPENDITURE']>max_value2].index, inplace=True)

# %%
#q75_rev_new,q25_rev_new=np.percentile(df8['TOTAL_REVENUE'], [75,25])
#new_iqr=q75_rev_new - q25_rev_new
#new_max_value=q75_rev_new + (new_iqr*1.5)
#new_min_value=q25_rev_new - (new_iqr*1.5)
#print(len(np.where(df8['TOTAL_REVENUE']>new_max_value))[0])

# %%
#df9=pd.DataFrame(df8[['TOTAL_REVENUE','TOTAL_EXPENDITURE']])
#df9

# %%
#df9.columns

# %%
#df8.drop(df8[(df8['TOTAL_REVENUE']>27622385.875)].index, inplace=True)
#df8.drop(df8[(df8['TOTAL_EXPENDITURE']> 27575952.625)].index, inplace=True)

# %%
#df8

# %%
#q3, q1=np.percentile(df8['TOTAL_REVENUE'], [75,25])
#iq_range=q3-q1
#max4=q3+(iq_range*1.5)
#min4=q1-(iq_range*1.5)
#print(len(df8.loc[(df8['TOTAL_REVENUE']>21246225)]))

# %%
#print(len(df8.loc[df8['TOTAL_REVENUE']>27622385.875]))

# %%
#print(len(df8.loc[df8['TOTAL_EXPENDITURE']>27575952.625]))

# %%
#variable=df8['TOTAL_REVENUE'].mean() - df8['TOTAL_EXPENDITURE'].mean()
#variable
#difference in average total revenue and average total expenditure = -30009.523914642632   after the outliers are eliminated

# %%
variable2=df8['TOTAL_REVENUE'].mean() - df8['TOTAL_EXPENDITURE'].mean()
variable2
# Out:
# -99439.54624664783

# %%
#using the original data, the difference = -99439.54624664783

# %%
#use winsorize

# %%
from scipy.stats.mstats import winsorize

# %%
total_rev_winsorized= winsorize(df8['TOTAL_REVENUE'], (0, 0.10))

# %%
plt.boxplot(total_rev_winsorized, whis=10)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a208ccf28>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a208d55f8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a208ccb38>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a208d5c88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a208d5fd0>],
#  'means': []}

# %%
total_exp_winsorized= winsorize(df8['TOTAL_EXPENDITURE'], (0, 0.05))

# %%
plt.boxplot(total_exp_winsorized, whis=10)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a2082f710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a2082fda0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a2082f320>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a20838470>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a208387b8>],
#  'means': []}

# %%
adjusted_budget=df8['TOTAL_REVENUE'] - df8['TOTAL_EXPENDITURE']
adjusted_budget
# Out:
# STATE
# ALABAMA    0        25087.0
#            51       -6042.0
#            102    -133043.0
#            153      14074.0
#            204    -207170.0
#            255      18164.0
#            306    -104496.0
#            357    -151264.0
#            408    -117350.0
#            459    -253099.0
#            510     -19262.0
#            561    -102878.0
#            612     -94156.0
#            663     -14698.0
#            714    -227401.0
#            765    -127419.0
#            816    -121174.0
#            870    -629077.0
#            922    -366513.0
#            974     -35043.0
#            1025    -85212.0
#            1076   -290302.0
#            1127   -230470.0
#            1178   -141577.0
#            1229   -210278.0
#            1441   -210278.0
# ALASKA     1        77103.0
#            52       65000.0
#            103     -63878.0
#            154     -86749.0
#                      ...
# WISCONSIN  1176     75067.0
#            1227     83699.0
# ...

# %%
plt.boxplot(adjusted_budget, whis=5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a20b08860>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a20b08ef0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a20b08470>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a20b0f5c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a20b0f908>],
#  'means': []}

# %%
adjusted_budget_winsorized = winsorize(adjusted_budget, (0.05, 0.05))

# %%
plt.boxplot(adjusted_budget_winsorized, whis=5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a20e2bba8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a20e2bfd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a20e2b7b8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a20e34908>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a20e34c50>],
#  'means': []}
