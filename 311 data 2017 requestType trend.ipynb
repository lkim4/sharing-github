# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('Downloads/MyLA311_Service_Request_Data_2017.csv')
column1=pd.DataFrame(df['CreatedDate'].astype(str).str.slice(stop=2)).reset_index(drop=True)
column2=pd.DataFrame(df['RequestType'].astype(str)).reset_index(drop=True)
df1=pd.DataFrame(column1.join(column2))
df1.columns=['month', 'request type']
df1.sort_values(by=['month'],ascending=True)
df1
# Out:
# /Users/laurakim/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         month                request type
# 0          04                 Bulky Items
# 1          04                 Bulky Items
# 2          04                 Bulky Items
# 3          04                 Bulky Items
# 4          04                 Bulky Items
# 5          04                 Bulky Items
# 6          04                 Bulky Items
# 7          04                 Bulky Items
# 8          04                 Bulky Items
# 9          04            Electronic Waste
# 10         04            Electronic Waste
# 11         04                 Bulky Items
# 12         04                 Bulky Items
# 13         04  Metal/Household Appliances
# 14         12            Electronic Waste
# ...

# %%
requestTypeCounts=pd.DataFrame(df1.groupby(['month'])['request type'].value_counts().reset_index(drop=True))

# %%
requestType2017=df1.groupby(['month','request type']).count().reset_index()
requestType2017['Counts']=requestTypeCounts['request type']
requestType2017
# Out:
#     month                request type  Counts
# 0      01                 Bulky Items   36377
# 1      01         Dead Animal Removal   29691
# 2      01            Electronic Waste    5415
# 3      01                    Feedback    5084
# 4      01            Graffiti Removal    3475
# 5      01         Homeless Encampment    1713
# 6      01      Illegal Dumping Pickup    1658
# 7      01  Metal/Household Appliances    1382
# 8      01  Multiple Streetlight Issue    1171
# 9      01                       Other     469
# 10     01          Report Water Waste     102
# 11     01    Single Streetlight Issue      39
# 12     02                 Bulky Items   30753
# 13     02         Dead Animal Removal   29562
# 14     02            Electronic Waste    4473
# 15     02                    Feedback    4221
# 16     02            Graffiti Removal    2873
# 17     02         Homeless Encampment    1454
# 18     02      Illegal Dumping Pickup    1447
# ...

# %%
trend2017=df1.groupby(df1['month'])['request type'].value_counts()
trend2017.plot(kind='bar', figsize=(25,8))
plt.title('total number of request per request type for each month')
plt.ylabel('total number of request')
plt.show()
