# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('Downloads/MyLA311_Service_Request_Data_2016.csv')
column1=pd.DataFrame(df['CreatedDate'].astype(str).str.slice(stop=2)).reset_index(drop=True)
column2=pd.DataFrame(df['RequestType'].astype(str)).reset_index(drop=True)
df1=pd.DataFrame(column1.join(column2))
df1.columns=['month', 'request type']
df1.sort_values(by=['month'],ascending=True)
df1
# Out:
# /Users/laurakim/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        month                request type
# 0         07      Illegal Dumping Pickup
# 1         07                 Bulky Items
# 2         07                 Bulky Items
# 3         07  Metal/Household Appliances
# 4         07                 Bulky Items
# 5         07      Illegal Dumping Pickup
# 6         07         Dead Animal Removal
# 7         07            Graffiti Removal
# 8         07                 Bulky Items
# 9         07                 Bulky Items
# 10        07      Illegal Dumping Pickup
# 11        07                 Bulky Items
# 12        07            Graffiti Removal
# 13        07                 Bulky Items
# 14        11          Report Water Waste
# 15        07            Graffiti Removal
# 16        07                 Bulky Items
# 17        07            Graffiti Removal
# 18        11                 Bulky Items
# 19        05                 Bulky Items
# 20        07            Graffiti Removal
# 21        07            Graffiti Removal
# 22        07            Graffiti Removal
# 23        07                 Bulky Items
# 24        07            Graffiti Removal
# 25        07            Graffiti Removal
# 26        07            Graffiti Removal
# 27        07            Graffiti Removal
# 28        05            Graffiti Removal
# 29        05            Graffiti Removal
# ...      ...                         ...
# 952723    01         Dead Animal Removal
# 952724    01         Dead Animal Removal
# 952725    01         Dead Animal Removal
# 952726    01         Dead Animal Removal
# 952727    01         Dead Animal Removal
# 952728    01         Dead Animal Removal
# 952729    01         Dead Animal Removal
# 952730    01         Dead Animal Removal
# 952731    01         Dead Animal Removal
# 952732    01         Dead Animal Removal
# 952733    01         Dead Animal Removal
# 952734    01         Dead Animal Removal
# 952735    01         Dead Animal Removal
# 952736    01         Dead Animal Removal
# 952737    01         Dead Animal Removal
# 952738    01         Dead Animal Removal
# 952739    01         Dead Animal Removal
# 952740    01         Dead Animal Removal
# 952741    01         Dead Animal Removal
# 952742    01         Homeless Encampment
# 952743    01         Dead Animal Removal
# 952744    01         Dead Animal Removal
# 952745    01         Dead Animal Removal
# 952746    01         Dead Animal Removal
# 952747    01         Dead Animal Removal
# 952748    01         Dead Animal Removal
# 952749    01         Dead Animal Removal
# 952750    01         Dead Animal Removal
# 952751    01         Dead Animal Removal
# 952752    01         Dead Animal Removal
#
# [952753 rows x 2 columns]

# %%
requestTypeCounts=pd.DataFrame(df1.groupby(['month'])['request type'].value_counts().reset_index(drop=True))

# %%
requestType2016=df1.groupby(['month','request type']).count().reset_index()
requestType2016['Counts']=requestTypeCounts['request type']
requestType2016
# Out:
#     month                request type  Counts
# 0      01                 Bulky Items   27939
# 1      01         Dead Animal Removal   17014
# 2      01            Electronic Waste    4097
# 3      01                    Feedback    3883
# 4      01            Graffiti Removal    3372
# 5      01         Homeless Encampment    1949
# 6      01      Illegal Dumping Pickup    1346
# 7      01  Metal/Household Appliances    1082
# 8      01  Multiple Streetlight Issue     451
# 9      01                       Other     444
# 10     01          Report Water Waste      46
# 11     01    Single Streetlight Issue      37
# 12     02                 Bulky Items   29693
# 13     02         Dead Animal Removal   24216
# 14     02            Electronic Waste    4186
# 15     02                    Feedback    3899
# 16     02            Graffiti Removal    3343
# 17     02         Homeless Encampment    1725
# 18     02      Illegal Dumping Pickup    1329
# 19     02  Metal/Household Appliances    1200
# 20     02  Multiple Streetlight Issue     443
# 21     02                       Other     308
# 22     02          Report Water Waste     107
# 23     02    Single Streetlight Issue      36
# 24     03                 Bulky Items   33916
# 25     03         Dead Animal Removal   27871
# 26     03            Electronic Waste    4809
# 27     03                    Feedback    4041
# 28     03            Graffiti Removal    3584
# 29     03         Homeless Encampment    1794
# ..    ...                         ...     ...
# 114    10      Illegal Dumping Pickup    1615
# 115    10  Metal/Household Appliances    1507
# 116    10  Multiple Streetlight Issue     944
# 117    10                       Other     295
# 118    10          Report Water Waste     146
# 119    10    Single Streetlight Issue      34
# 120    11                 Bulky Items   32795
# 121    11         Dead Animal Removal   25353
# 122    11            Electronic Waste    5065
# 123    11                    Feedback    4379
# 124    11            Graffiti Removal    3270
# 125    11         Homeless Encampment    1749
# 126    11      Illegal Dumping Pickup    1431
# 127    11  Metal/Household Appliances    1111
# 128    11  Multiple Streetlight Issue    1087
# 129    11                       Other     388
# 130    11          Report Water Waste     100
# 131    11    Single Streetlight Issue      29
# 132    12                 Bulky Items   32294
# 133    12         Dead Animal Removal   27825
# 134    12            Electronic Waste    4977
# 135    12                    Feedback    4149
# 136    12            Graffiti Removal    3604
# 137    12         Homeless Encampment    1622
# 138    12      Illegal Dumping Pickup    1458
# 139    12  Metal/Household Appliances    1067
# 140    12  Multiple Streetlight Issue    1007
# 141    12                       Other     441
# 142    12          Report Water Waste      83
# 143    12    Single Streetlight Issue      33
#
# [144 rows x 3 columns]

# %%
trend2016=df1.groupby(df1['month'])['request type'].value_counts()
trend2016.plot(kind='bar', figsize=(25,8))
plt.title('total number of request per request type for each month')
plt.ylabel('total number of request')
plt.show()
