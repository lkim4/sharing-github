# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
data=pd.read_csv("/Users/laurakim/Downloads/crimes-in-boston/crime.csv", engine="python")
data1=data.loc[0:50, :]
data1
# Out:
#    INCIDENT_NUMBER  OFFENSE_CODE                OFFENSE_CODE_GROUP  \
# 0       I182070945           619                           Larceny
# 1       I182070943          1402                         Vandalism
# 2       I182070941          3410                             Towed
# 3       I182070940          3114              Investigate Property
# 4       I182070938          3114              Investigate Property
# 5       I182070936          3820   Motor Vehicle Accident Response
# 6       I182070933           724                        Auto Theft
# 7       I182070932          3301                   Verbal Disputes
# 8       I182070931           301                           Robbery
# 9       I182070929          3301                   Verbal Disputes
# 10      I182070928          3301                   Verbal Disputes
# 11      I182070927          3114              Investigate Property
# 12      I182070923          3108              Fire Related Reports
# ...

# %%
#1: choose one variable, plot it four different ways

# %%
#data['OFFENSE_CODE'].value_counts()

# %%
#data.shape

# %%
#https://seaborn.pydata.org/tutorial/categorical.html
#variable of choice: OFFENSE_CODE Column: this is a categorical data plot. 
#scatterplot: swarmplot()
#distribution plot: boxplot(), violinplot()
#estimate plot: countplot()

# %%
#scatterplot: swarmplot(with kind="swarm"): 
#ax = sns.swarmplot(x=tips["total_bill"])
sns.set(style="whitegrid")
ax=sns.swarmplot(x=data1['OFFENSE_CODE'])
ax.set(xlabel="Offense code", ylabel="frequency")
# Out:
# [Text(0, 0.5, 'frequency'), Text(0.5, 0, 'Offense code')]

# %%
ax=sns.violinplot(x=data1['OFFENSE_CODE'])
#So actual x axis only exist where the black line is???

# %%
#distribution plot: boxplot(with kind="box"):
#ax=sns.boxplot(x=data1['OFFENSE_CODE'])

# %%
#data2=pd.DataFrame(data1['OFFENSE_CODE'].value_counts().reset_index())
#data2

# %%
ax=sns.boxplot(x="index", y="OFFENSE_CODE", data=data2)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_ylabel("offense code count")
ax.set_xlabel("offense code")
ax.set_title("offense code counts")
# Out:
# Text(0.5, 1.0, 'offense code counts')

# %%
ax=sns.countplot(x=data1['OFFENSE_CODE'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_title("Offense code total number of counts")
# Out:
# Text(0.5, 1.0, 'Offense code total number of counts')

# %%
#2: Choose two continuous variables, and plot them three different ways: data1['DAY_OF_WEEK'] and 
#data1['HOUR'] columns

# %%
data1['OCCURRED_ON_DATE'].dtype
# Out:
# dtype('O')

# %%
data1['OCCURRED_ON_DATE']=pd.to_datetime(data1['OCCURRED_ON_DATE'])
# Out:
# /Users/laurakim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
xaxis=data1['OCCURRED_ON_DATE'].dt.month

# %%
ax=sns.barplot(x="DAY_OF_WEEK", y="HOUR", data=data1)
ax.set(xlabel='month')
# Out:
# [Text(0.5, 0, 'month')]

# %%
ax=sns.lineplot(x="DAY_OF_WEEK", y="HOUR", data=data1)
#is this graph just showing the average 'HOUR' for each day of week?? I think yaxis is just the total number of
#crime report for days of week

# %%
sns.stripplot(x="DAY_OF_WEEK", y="HOUR", data=data1)
#so this graph shows how many crime reports occur during what hour for each day of week
#that's cool, cause you can compare this to other months as well (I think this is only for the month of August and Sept)
#and check for any high volume during certain hours, etc.  I think this graph and the bar graphs are the best ones
#to use for these variables.

# %%
#3: Choose one continuous variable and one categorical variable, and plot them six different ways: 
#continuous variable: HOUR
#categorical variable: OFFENSE_CODE

# %%
sns.barplot(x='HOUR', y='OFFENSE_CODE', data=data1)
#this is not a good one to use because OFFENSE_CODE numbers are not considered as separate values. 
#It shouldn't take the average,STD of OFFENSE_CODE.
#what if I switch x and y?

# %%
ax=sns.barplot(x='OFFENSE_CODE', y='HOUR', data=data1)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '301'),
#  Text(0, 0, '522'),
#  Text(0, 0, '613'),
#  Text(0, 0, '614'),
#  Text(0, 0, '619'),
#  Text(0, 0, '724'),
#  Text(0, 0, '802'),
#  Text(0, 0, '1402'),
#  Text(0, 0, '1841'),
#  Text(0, 0, '1843'),
#  Text(0, 0, '2007'),
#  Text(0, 0, '2612'),
#  Text(0, 0, '2629'),
#  Text(0, 0, '2647'),
#  Text(0, 0, '2662'),
#  Text(0, 0, '2900'),
#  Text(0, 0, '2907'),
#  Text(0, 0, '3006'),
#  Text(0, 0, '3018'),
#  Text(0, 0, '3108'),
#  Text(0, 0, '3109'),
#  Text(0, 0, '3114'),
#  Text(0, 0, '3125'),
#  Text(0, 0, '3201'),
#  Text(0, 0, '3207'),
#  Text(0, 0, '3301'),
#  Text(0, 0, '3305'),
#  Text(0, 0, '3410'),
#  Text(0, 0, '3801'),
#  Text(0, 0, '3802'),
#  Text(0, 0, '3803'),
#  Text(0, 0, '3820'),
#  Text(0, 0, '3831')]

# %%
#switching x and y axis probably makes more sense.  Cause at least that shows time range that each offense code
#gets reported

# %%
sns.stripplot(x='HOUR', y='OFFENSE_CODE', data=data1)

# %%
sns.relplot(x='OFFENSE_CODE', y='HOUR', data=data1)

# %%
sns.relplot(x="HOUR", y="OFFENSE_CODE", kind="line", data=data1)
#not a good one to use for continuous and categorical variables...

# %%
s=sns.swarmplot(x="OFFENSE_CODE", y="HOUR", data=data1)
s.set_xticklabels(s.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '301'),
#  Text(0, 0, '522'),
#  Text(0, 0, '613'),
#  Text(0, 0, '614'),
#  Text(0, 0, '619'),
#  Text(0, 0, '724'),
#  Text(0, 0, '802'),
#  Text(0, 0, '1402'),
#  Text(0, 0, '1841'),
#  Text(0, 0, '1843'),
#  Text(0, 0, '2007'),
#  Text(0, 0, '2612'),
#  Text(0, 0, '2629'),
#  Text(0, 0, '2647'),
#  Text(0, 0, '2662'),
#  Text(0, 0, '2900'),
#  Text(0, 0, '2907'),
#  Text(0, 0, '3006'),
#  Text(0, 0, '3018'),
#  Text(0, 0, '3108'),
#  Text(0, 0, '3109'),
#  Text(0, 0, '3114'),
#  Text(0, 0, '3125'),
#  Text(0, 0, '3201'),
#  Text(0, 0, '3207'),
#  Text(0, 0, '3301'),
#  Text(0, 0, '3305'),
#  Text(0, 0, '3410'),
#  Text(0, 0, '3801'),
#  Text(0, 0, '3802'),
#  Text(0, 0, '3803'),
#  Text(0, 0, '3820'),
#  Text(0, 0, '3831')]

# %%
#I think graphing continuous and categorial variables against each other gives similar looking graphs in the end.

# %%
df=pd.read_csv("/Users/laurakim/Downloads/world-happiness-report/2015.csv")
df
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
sns.lmplot(x='Freedom', y='Happiness Score', hue='Region', data=df)

# %%
#as you move away from freedom score of 0.3-0.5 (in both directions),
#happiness score standard error gets wider.  
# except Southeastern Asia, Eastern Asia and Australia and New Zealand regions, increase in freedom score
#seems to result in increase in happiness score
#relationship between freedom score and happiness score varies among different regions (some show positive, 
#some show negative, and others almost no relationship): based on the lines.  
#freedom score around 0.3-0.5 and happiness score close to 5 (where most lines cross each other):
#lines for regions that do not seem to have relationship between freedom score and happiness score (Eastern Asia and Australia 
#and New Zealand) do not seem to cross that point.
#perhaps in regions where freedom is related to level of happiness, 
#maybe we could assume that freedom score of about 0.3-0.5 could generate happiness
#score around 5.  However, as we move below and above that freedom score of 0.3-0.5, it's difficult to predict
#the direction and degree of happiness level depending on the region.

# %%
sns.scatterplot(x='Freedom', y='Happiness Score', hue='Region', data=df)
